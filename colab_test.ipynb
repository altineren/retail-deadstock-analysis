# %% [markdown]
# # Google Colab Test Notebook
# This notebook is created locally to confirm that the Colab extension in VS Code can open and run it.

# %%
import sys
print(f'Python executable: {sys.executable}')
print('If you can run this cell in Colab, the extension works!')
# Out:
# Python executable: /usr/bin/python3
# If you can run this cell in Colab, the extension works!
